# %%
from network import InterBankNetwork

from graphics import Graphics

network = InterBankNetwork(
        n_banks=50,
        alpha_pareto=0.5,
        perc_deposit_shock=0.1,
        beta_lcr=10.0,
        beta_star_lcr=10.0,
        initial_mr=1.0,
        initial_l2s=3.0,
        collateral_value=1.0,
        init="constant",
        shock_method="dirichlet",
        constant_dirichlet=1,
    )

# %% [markdown]
# # with constant initialization

# %%
network.simulate(100)

Graphics(network).plot_network()
# Out:
#  25%|███████████████████████████████████████████████                                                                                                                                             | 25/100 [00:00<00:02, 35.90it/s]C:\Users\VictorLeCoz\OneDrive - Quant Decisions S.L\Documents\PhD\secured-inter-bank-network\bank.py:152: RuntimeWarning: invalid value encountered in double_scalars
#   return self.assets["Cash"] / self.liabilities["Deposits"]
#  25%|███████████████████████████████████████████████                                                                                                                                             | 25/100 [00:00<00:02, 35.70it/s]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 network.simulate(100)
#       3 Graphics(network).plot_network()
#
# File ~\OneDrive - Quant Decisions S.L\Documents\PhD\secured-inter-bank-network\network.py:120, in InterBankNetwork.simulate(self, time_steps)
#     118 def simulate(self, time_steps):
#     119     for _ in tqdm(range(time_steps)):
# --> 120         self.step_network()
#
# File ~\OneDrive - Quant Decisions S.L\Documents\PhD\secured-inter-bank-network\network.py:91, in InterBankNetwork.step_network(self)
#      89 total_mro = 0.0
#      90 for i in ix:
# ---> 91     self.banks[i].assert_minimal_reserve()
#      92     self.banks[i].assert_alm()
#      93     self.banks[i].assert_lcr()
#
# File ~\OneDrive - Quant Decisions S.L\Documents\PhD\secured-inter-bank-network\bank.py:178, in BankAgent.assert_minimal_reserve(self)
#     177 def assert_minimal_reserve(self):
# --> 178     assert (
#     179         self.cash_to_deposits() + 1e-8 >= self.alpha
#     180     ), self.__str__() + "\nMinimum reserves not respected for bank {} at step {}".format(
#     181         self.id, self.steps
#     182     )
#
# AssertionError: Bank 23
#         ----------------------------------------
#         Total Assets: 102.09
#         ----Cash: 0.0
#         ----Securities Usable: 0.0
#         ----Securities Encumbered: 9.0
#         ----Reverse Repos: 0.0
#         ----Loans: 93.09
#         ----------------------------------------
#         Total Liabilities: 102.09
#         ----Own Funds: 3.09
#         ----Deposits: 0.0
#         ----Repos: 9.0
#         ----MROs: 90.0
#         ----------------------------------------
#         Off-balance sheet Items:
#         ----Collateral received: 0.0
#         ----Collateral Reuse: 0.0
#         ----------------------------------------
#         Regulatory:
#         ----Liquidity Coverage Ratio: inf%
#         ----Cash / Deposits (for minimal reserves): nan%
#         ----Leverage / Solvency ratio: 3.03%
#
# Minimum reserves not respected for bank 23 at step 36

# %% [markdown]
# # with power law initialization

# %%
network = simulate(n_banks=25,
    alpha_pareto=0.5,
    perc_deposit_shock=0.1,
    beta_lcr=10.0,
    beta_star_lcr=10.0,
    initial_mr=1.0,
    initial_l2s=3.0,
    collateral_value=1.0,
    init="pareto",
    time_step=1)

Graphics(network).plot_network()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 162.54it/s]

# %%
for i in range(1):
    print(i)
# Out:
# 0

# %%
import numpy as np
dispatch  = np.random.dirichlet(np.ones(25)*10000)
plt.plot(dispatch)
print(np.abs(dispatch.min()-dispatch.mean()),np.abs(dispatch.max()-dispatch.mean()))
# Out:
# 0.001078842316820816 0.0007950374904959062

# %%
dispatch.mean()
# Out:
# 0.010000000000000002

# %%
dispatch[16]
# Out:
# 0.23169359601742923

# %%
1/25
# Out:
# 0.04
