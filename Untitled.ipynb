# %%
from network import InterBankNetwork

from graphics import Graphics

network = InterBankNetwork(
        n_banks=25,
        alpha_pareto=0.5,
        perc_deposit_shock=0.1,
        beta_lcr=10.0,
        beta_star_lcr=10.0,
        initial_mr=1.0,
        initial_l2s=3.0,
        collateral_value=1.0,
        init="const",
        shock_method="dirichlet",
        constant_dirichlet=10,
    )

# %% [markdown]
# # with constant initialization

# %%
network.simulate(500)

Graphics(network).plot_network()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 500/500 [00:02<00:00, 216.13it/s]

# %%
import numpy as np
np.diag(network.adj_matrix)
# Out:
# array([0.        , 0.        , 0.        , 0.        , 0.        ,
#        0.        , 0.        , 0.05332253, 0.        , 0.        ,
#        0.        , 0.        , 0.        , 0.        , 0.        ,
#        0.13136156, 0.        , 0.        , 0.08372555, 0.        ,
#        0.        , 0.        , 0.        , 0.        , 0.        ])

# %% [markdown]
# # with power law initialization

# %%
network = simulate(n_banks=25,
    alpha_pareto=0.5,
    perc_deposit_shock=0.1,
    beta_lcr=10.0,
    beta_star_lcr=10.0,
    initial_mr=1.0,
    initial_l2s=3.0,
    collateral_value=1.0,
    init="pareto",
    time_step=1)

Graphics(network).plot_network()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 162.54it/s]

# %%
for i in range(1):
    print(i)
# Out:
# 0

# %%
import numpy as np
dispatch  = np.random.dirichlet(np.ones(25)*10000)
plt.plot(dispatch)
print(np.abs(dispatch.min()-dispatch.mean()),np.abs(dispatch.max()-dispatch.mean()))
# Out:
# 0.001078842316820816 0.0007950374904959062

# %%
dispatch.mean()
# Out:
# 0.010000000000000002

# %%
dispatch[16]
# Out:
# 0.23169359601742923

# %%
1/25
# Out:
# 0.04
